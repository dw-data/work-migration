# %%
import pandas as pd
import datetime
import altair as alt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-56437de010c2> in <module>
#       1 import pandas as pd
#       2 import datetime
# ----> 3 import altair as alt
#
# ModuleNotFoundError: No module named 'altair'

# %%
df = pd.read_csv('../data/data_restrictions.csv', encoding ='latin-1')
df.head()
# Out:
# c:\python39\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (23,25,26,27,28,30,31,32,33,34,35,37,38,39,48,51,55,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    unit            record_id policy_id entry_type update_type update_level  \
# 0     1  R_3FKlACY6Djr1sjcNA   2975738  new_entry         NaN          NaN
# 1     1  R_2arWTemRbMLKdk0NA   7024226  new_entry         NaN          NaN
# 2     1  R_1reUk0mSCc6qdXWNA   1850843  new_entry         NaN          NaN
# 3     1  R_pMJfXPNXIYRVx9TNA    889484  new_entry         NaN          NaN
# 4     1  R_1eJC2cHJL6SXEq9NA    769460  new_entry         NaN          NaN
#
#   update_level_var                                        description  \
# 0              NaN  March 6, Afghanistan "Measures have been taken...
# 1              NaN  March 16, In Afghanistan the Government Media ...
# 2              NaN  On May 14, 2020 it was announced that the gove...
# 3              NaN  Afghanistan, May 28 "a government livelihood s...
# 4              NaN  On May 28, 2020 it was announced that in Afgha...
#
#   date_announced  date_start  ...                              compliance  \
# 0     2020-03-06  2020-03-06  ...  Voluntary/Recommended but No Penalties
# 1     2020-03-16  2020-03-16  ...         Mandatory (Unspecified/Implied)
# 2     2020-05-14  2020-05-14  ...         Mandatory (Unspecified/Implied)
# 3     2020-05-28  2020-05-28  ...  Voluntary/Recommended but No Penalties
# 4     2020-05-28  2020-05-28  ...         Mandatory (Unspecified/Implied)
#
#                                             enforcer dist_index_high_est  \
# 0  Ministry/Department of Health,Other (Please sp...           52.916078
# 1  National Government,New (COVID-19 specific) Ta...           52.686462
# 2                                National Government           84.670916
# 3  National Government,Other (Please specify in t...           85.831683
# 4  National Government,New (COVID-19 specific) Ta...           85.831683
#
#   dist_index_med_est dist_index_low_est dist_index_country_rank  \
# 0          44.303241          34.858501                   123.0
# 1          45.558520          36.720212                    60.0
# 2          77.764484          70.084312                   125.0
# 3          79.827249          73.137634                   131.0
# 4          79.827249          73.137634                   131.0
#
#                                             pdf_link  \
# 0  https://tummgmt.eu.qualtrics.com/Q/File.php?F=...
# 1  https://tummgmt.eu.qualtrics.com/Q/File.php?F=...
# 2  https://tummgmt.eu.qualtrics.com/Q/File.php?F=...
# 3  https://tummgmt.eu.qualtrics.com/Q/File.php?F=...
# 4  https://tummgmt.eu.qualtrics.com/Q/File.php?F=...
#
#                                                 link date_updated  \
# 0  https://www.etilaatroz.com/94246/fears-rumors-...   2021-08-15
# 1  https://www.gmic.gov.af/dari/press-releases2/4...   2021-08-15
# 2  https://web.archive.org/web/20200605000709/htt...   2021-12-11
# 3  https://www.worldbank.org/en/news/feature/2020...   2021-08-15
# 4  https://web.archive.org/web/20200605001328/htt...   2021-12-11
#
#           recorded_date
# 0  2021-08-15T16:53:01Z
# 1  2021-08-15T16:57:33Z
# 2  2021-12-11T09:07:32Z
# 3  2021-08-15T17:14:59Z
# 4  2021-12-11T10:26:57Z
#
# [5 rows x 67 columns]

# %%
df['parsed_start_date'] = pd.to_datetime(df['date_start'], format='%Y-%m-%d')
df['parsed_end_date'] = pd.to_datetime(df['date_end'], format='%Y-%m-%d')

# %%
earliest_start = df['parsed_start_date'].min()
latest_end = df['parsed_end_date'].max()

# %%
delta = datetime.timedelta(days=1)

# %%
inspect_date = earliest_start # start with the earliest possible date

list_of_restrictions_by_date=[]

while(inspect_date <= latest_end): # for as long as the the date to inspect is smaller or equal the latest end date
    date_dict = {} # create and empty dictionary to later store retrieved values
    date_dict['date']=inspect_date # save inspected date into said dictionary
    # filter df for entries smaller start dates or larger end dates:
    df_temp = df[(df['parsed_start_date']<=inspect_date)&(df['parsed_end_date']>=inspect_date)]  
    date_dict['restrictions_on_date'] = len(df_temp) # length of filtered df equals number of restrictions on that date
    
    list_of_restrictions_by_date.append(date_dict) # add date dict to list
    
    inspect_date = inspect_date + delta # put date counter one day up

df_restrictions_by_date = pd.DataFrame(list_of_restrictions_by_date)  # convert list to dataframe
df_restrictions_by_date # show dataframe
# Out:
#            date  restrictions_on_date
# 0    2019-12-31                     2
# 1    2020-01-01                     3
# 2    2020-01-02                     2
# 3    2020-01-03                     2
# 4    2020-01-04                     2
# ...         ...                   ...
# 2735 2027-06-27                     1
# 2736 2027-06-28                     1
# 2737 2027-06-29                     1
# 2738 2027-06-30                     1
# 2739 2027-07-01                     1
#
# [2740 rows x 2 columns]

# %%
alt.Chart(df_restrictions_by_date).mark_line().encode(
    x='date',
    y='restrictions_on_date'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-82cb215d0e19> in <module>
# ----> 1 alt.Chart(df_restrictions_by_date).mark_line().encode(
#       2     x='date',
#       3     y='restrictions_on_date'
#       4 )
#
# NameError: name 'alt' is not defined
